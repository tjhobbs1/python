# %% [markdown]
# # Module 5

# %% [markdown]
# ### First, a quick review
# ### The types of programs we've learned so far:

# %% [markdown]
# ### Sequential
# ![Sequential%20Program%20Diagram.png](attachment:Sequential%20Program%20Diagram.png)

# %% [markdown]
# ### Selection
# ![Selection%20Program%20Diagram.png](attachment:Selection%20Program%20Diagram.png)

# %% [markdown]
# ### Now we're going to learn about:

# %% [markdown]
# ### Iterative (looping)
# ![Iterative%20Program%20Diagram.png](attachment:Iterative%20Program%20Diagram.png)

# %% [markdown]
# ![Loop1.png](attachment:Loop1.png)

# %% [markdown]
# ## Topic 1: for loops and range

# %% [markdown]
# ### for loops allow for an established number of iterations through a section of code.
#
# ### for loops can iterate a set number of times or through each item of a list, tuple, or dictionary

# %% [markdown]
# ### This is an example of a for loop that loops a specified number of times:

# %%
# Fibonacci sequence 0,1,1,2,3,5,8,13,21, etc. 
# It takes the sum of the previous two numbers to make the next number in the sequence
fib_1 = 0
fib_2 = 1
for x in range(15):
    print(fib_1)
    temp = fib_1 
    fib_1 = fib_2
    fib_2 = temp + fib_2

# %% [markdown]
# ### This one actually uses the for count variable in the loop:

# %%
msum = 0
for m in range(5):
    msum += m
print(msum)

# %% [markdown]
# ### for loops don't have to start at index 0.
# ### You can set a range and step size.
# ### This example counts starting at 3 with steps of size 3 ending when it is 14 or greater

# %%
for m in range(3,14,3):
    print(m)

# %% [markdown]
# ### This is an example of a for loop that iterates through a list

# %%
mynumberlist=[1.5,55.5,1103.7,27.5,88,93,15]
sum_up = 0
mult = 1
for x in mynumberlist:
    sum_up += x
    mult *= x
print (sum_up, mult)

# %% [markdown]
# ## Topic 2: The while loop
# ![Iterative%20Program%20Diagram.png](attachment:Iterative%20Program%20Diagram.png)

# %% [markdown]
# ### while loops will continue to loop until a set condition is acheived.
# ### This is where you'll surely get to experience the infinite loop (of doom)

# %% [markdown]
# ### This first example is a loop that continues until the user enters enough numbers to make the total of x bigger than 25

# %%
# Simple while loop
# This while loop exits when the user's total integers entered get bigger than 25
x = 0
while x  <= 25:
    x += int(input('enter an integer to add up:'))

print("Your number is ",x,", which is bigger than 25", sep='')

# %% [markdown]
# ### This example includes a sentinel value in the loop.
# ### The user is deciding when they want to be done by typing 'done' at the input

# %%
# This while loop has a sentinel value of 'done' to let the user stop entering items in the list
user_list=[]
user_list_input = ''
while user_list_input != 'done':
    user_list.append(user_list_input)
    user_list_input = input("enter a list item or 'done' when you are complete: ")
    
del user_list[0]
print("Here's your list:")
print(user_list)

# %% [markdown]
# ### while loops have a lot of uses.
# ### One common use is combining a while loop with a try-except process

# %%
user_input = 'error'
while user_input == 'error':
    try:
        user_input = int(input('input a whole number: '))
    except: 
        print("You didn't enter a whole number!")
        user_input = 'error'
print("Thanks for entering the number:", user_input)

# %% [markdown]
# ## Topic 3: Use break, else, and continue in Loops

# %% [markdown]
# ### There are times when you want to interrupt your loops for certain conditions

# %% [markdown]
# ### We have several ways of doing this.
# ### In this example, we break out of a for loop early using the "break" command:

# %%
list_of_words = ['word1', 'word2', 'word3', 'word4', 'sandwich', 'word6', 'word7', 'word8']
word_count=0
for x in list_of_words:
    word_count+=1
    if x == 'sandwich':
        break
print(x)
print(word_count)

# %% [markdown]
# ### Breaks can be done within both for and while loops

# %% [markdown]
# ### We could also use a "continue" command like in this example:

# %%
for val in "syntactically":
    if val in ["a","e","i","o","u","y"]:
        continue
    else:
        print(val)
# Out:
# s
# n
# t
# c
# t
# c
# l
# l

# %% [markdown]
# ### The difference between a break and a continue is that a break exits the loop entirely but the continue only exits one iteration of the loop
#
# ![break%20and%20continue%20flows.jpg](attachment:break%20and%20continue%20flows.jpg)

# %% [markdown]
# ### If you don't know what syntactically correct means, it means that the syntax is correct...

# %% [markdown]
# ### Else commands can also be used with loops.
# ### An else command is only executed if the loop completes without a break happening

# %%
user_input = ""
user_list =[]
input_count = -1
while user_input != 'done':
    user_input = input("Give a word, enter 'done' when you are complete, or 'quit' to exit: ")
    if user_input == 'quit':
        break
    user_list.append(user_input)
    input_count += 1
else:
    del user_list[input_count]
    print('Your list: ',*user_list)
